# %% [markdown]
# # Basic부터 복습!

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Q. pandas/data/pokemon.csv를 불러와보세요. index는 Number로 설정!
# Tip: 현재 폴더에서 상위폴더로 가려면 ../ 를 사용하세요!
# "../pandas/data/pokemon.csv"

# %%
pokemon =

# %%
# Answer
pokemon.head()
# Out:
#               Name Type_1  Type_2  Total  HP  Attack  Defense  Speed  \
# Number
# 1        Bulbasaur  Grass  Poison    318  45      49       49     45
# 2          Ivysaur  Grass  Poison    405  60      62       63     60
# 3         Venusaur  Grass  Poison    525  80      82       83     80
# 4       Charmander   Fire     NaN    309  39      52       43     65
# 5       Charmeleon   Fire     NaN    405  58      64       58     80
#
#         Generation  isLegendary  Color  hasGender  Height_m  Weight_kg  \
# Number
# 1                1        False  Green       True      0.71        6.9
# 2                1        False  Green       True      0.99       13.0
# 3                1        False  Green       True      2.01      100.0
# 4                1        False    Red       True      0.61        8.5
# 5                1        False    Red       True      1.09       19.0
#
#         Catch_Rate      Body_Style
# Number
# 1               45       quadruped
# ...

# %% [markdown]
# #### Q. pokemon에서 Name column만 불러와보세요.

# %%
# Answer
# Out:
# Number
# 1       Bulbasaur
# 2         Ivysaur
# 3        Venusaur
# 4      Charmander
# 5      Charmeleon
# 6       Charizard
# 7        Squirtle
# 8       Wartortle
# 9       Blastoise
# 10       Caterpie
# 11        Metapod
# 12     Butterfree
# 13         Weedle
# 14         Kakuna
# 15       Beedrill
# 16         Pidgey
# 17      Pidgeotto
# 18        Pidgeot
# 19        Rattata
# 20       Raticate
# 21        Spearow
# 22         Fearow
# 23          Ekans
# 24          Arbok
# 25        Pikachu
# 26         Raichu
# 27      Sandshrew
# 28      Sandslash
# 29       Nidoran♀
# 30       Nidorina
#           ...
# 692     Clauncher
# 693     Clawitzer
# 694    Helioptile
# 695     Heliolisk
# 696        Tyrunt
# 697     Tyrantrum
# 698        Amaura
# 699       Aurorus
# 700       Sylveon
# 701      Hawlucha
# 702       Dedenne
# 703       Carbink
# 704         Goomy
# 705       Sliggoo
# 706        Goodra
# 707        Klefki
# 708      Phantump
# 709     Trevenant
# ...

# %% [markdown]
# #### Q. pokemon에서 Name, Type_1 column들을 한번에 불러와보세요.

# %%
# Answer
# Out:
#               Name Type_1
# Number
# 1        Bulbasaur  Grass
# 2          Ivysaur  Grass
# 3         Venusaur  Grass
# 4       Charmander   Fire
# 5       Charmeleon   Fire

# %% [markdown]
# #### Q. pokemon에서 각 column의 결측치 비율을 찾아보세요!
# Tip) 세션에서 한 len() 보다 더 쉬운 뭔가가 있을 거 같은데...?

# %%
# Answer
# Out:
# Name           0.000000
# Type_1         0.000000
# Type_2         0.514563
# Total          0.000000
# HP             0.000000
# Attack         0.000000
# Defense        0.000000
# Speed          0.000000
# Generation     0.000000
# isLegendary    0.000000
# Color          0.000000
# hasGender      0.000000
# Height_m       0.000000
# Weight_kg      0.000000
# Catch_Rate     0.000000
# Body_Style     0.000000
# dtype: float64

# %% [markdown]
# #### Q. pokemon에서 모든 결측치를 None으로 채워보세요.
# 주의) pokemon 원본 데이터에 직접 수정하지 마세요!

# %%
pokemon_fillna =

# %%
# Answer
pokemon_fillna.head()
# Out:
#               Name Type_1  Type_2  Total  HP  Attack  Defense  Speed  \
# Number
# 1        Bulbasaur  Grass  Poison    318  45      49       49     45
# 2          Ivysaur  Grass  Poison    405  60      62       63     60
# 3         Venusaur  Grass  Poison    525  80      82       83     80
# 4       Charmander   Fire    None    309  39      52       43     65
# 5       Charmeleon   Fire    None    405  58      64       58     80
#
#         Generation  isLegendary  Color  hasGender  Height_m  Weight_kg  \
# Number
# 1                1        False  Green       True      0.71        6.9
# 2                1        False  Green       True      0.99       13.0
# 3                1        False  Green       True      2.01      100.0
# 4                1        False    Red       True      0.61        8.5
# 5                1        False    Red       True      1.09       19.0
#
#         Catch_Rate      Body_Style
# Number
# 1               45       quadruped
# ...

# %% [markdown]
# #### Q. pokemon의 bmi를 계산해서 BMI column을 새로 추가해봅시다.
# Tip) BMI = Weight(kg) / Height(m)*Height(m)

# %%
# Answer
pokemon.head()
# Out:
#               Name Type_1  Type_2  Total  HP  Attack  Defense  Speed  \
# Number
# 1        Bulbasaur  Grass  Poison    318  45      49       49     45
# 2          Ivysaur  Grass  Poison    405  60      62       63     60
# 3         Venusaur  Grass  Poison    525  80      82       83     80
# 4       Charmander   Fire     NaN    309  39      52       43     65
# 5       Charmeleon   Fire     NaN    405  58      64       58     80
#
#         Generation  isLegendary  Color  hasGender  Height_m  Weight_kg  \
# Number
# 1                1        False  Green       True      0.71        6.9
# 2                1        False  Green       True      0.99       13.0
# 3                1        False  Green       True      2.01      100.0
# 4                1        False    Red       True      0.61        8.5
# 5                1        False    Red       True      1.09       19.0
#
#         Catch_Rate      Body_Style        BMI
# Number
# 1               45       quadruped  13.687760
# ...

# %% [markdown]
# #### Q. Total의 값이 600 이상인 강한 포켓몬을 찾아 isStrong에 강하면 1, 약하면 0을 넣어봅시다.

# %%
pokemon.head()
# Out:
#               Name Type_1  Type_2  Total  HP  Attack  Defense  Speed  \
# Number
# 1        Bulbasaur  Grass  Poison    318  45      49       49     45
# 2          Ivysaur  Grass  Poison    405  60      62       63     60
# 3         Venusaur  Grass  Poison    525  80      82       83     80
# 4       Charmander   Fire     NaN    309  39      52       43     65
# 5       Charmeleon   Fire     NaN    405  58      64       58     80
#
#         Generation  isLegendary  Color  hasGender  Height_m  Weight_kg  \
# Number
# 1                1        False  Green       True      0.71        6.9
# 2                1        False  Green       True      0.99       13.0
# 3                1        False  Green       True      2.01      100.0
# 4                1        False    Red       True      0.61        8.5
# 5                1        False    Red       True      1.09       19.0
#
#         Catch_Rate      Body_Style        BMI  isStrong
# Number
# ...

# %% [markdown]
# #### Q. DataFrame에서 Number의 값이 150 이상 160 미만인 row만 뽑아봅시다.
# cf) 조건문 말고 slicing 합시다!

# %%
# Answer
# Out:
#               Name   Type_1 Type_2  Total   HP  Attack  Defense  Speed  \
# Number
# 150         Mewtwo  Psychic    NaN    680  106     110       90    130
# 151            Mew  Psychic    NaN    600  100     100      100    100
# 152      Chikorita    Grass    NaN    318   45      49       65     45
# 153        Bayleef    Grass    NaN    405   60      62       80     60
# 154       Meganium    Grass    NaN    525   80      82      100     80
# 155      Cyndaquil     Fire    NaN    309   39      52       43     65
# 156        Quilava     Fire    NaN    405   58      64       58     80
# 157     Typhlosion     Fire    NaN    534   78      84       78    100
# 158       Totodile    Water    NaN    314   50      65       64     43
# 159       Croconaw    Water    NaN    405   65      80       80     58
#
#         Generation  isLegendary   Color  hasGender  Height_m  Weight_kg  \
# Number
# 150              1         True  Purple      False      2.01      122.0
# ...

# %% [markdown]
# #### Q. Type_1이 Fairy인 포켓몬의 이름들을 찾아봅시다!

# %%
# Answer
pokemon[lambda x: x["Type_1"]=="Fairy"]["Name"]
# Out:
# Number
# 35       Clefairy
# 36       Clefable
# 173        Cleffa
# 175        Togepi
# 176       Togetic
# 209      Snubbull
# 210      Granbull
# 468      Togekiss
# 669       Flabébé
# 670       Floette
# 671       Florges
# 682      Spritzee
# 683    Aromatisse
# 684       Swirlix
# 685      Slurpuff
# 700       Sylveon
# 716       Xerneas
# Name: Name, dtype: object

# %% [markdown]
# #### Q. Generation으로 groupby를 해줍시다

# %%
grouped =

# %%
# Answer
grouped

# %% [markdown]
# #### Q. grouped에서 3세대 포켓몬만 봅시다

# %%
# Answer
# Out:
#              Name   Type_1    Type_2  Total   HP  Attack  Defense  Speed  \
# Number
# 252       Treecko    Grass       NaN    310   40      45       35     70
# 253       Grovyle    Grass       NaN    405   50      65       45     95
# 254      Sceptile    Grass       NaN    530   70      85       65    120
# 255       Torchic     Fire       NaN    310   45      60       40     45
# 256     Combusken     Fire  Fighting    405   60      85       60     55
# 257      Blaziken     Fire  Fighting    530   80     120       70     80
# 258        Mudkip    Water       NaN    310   50      70       50     40
# 259     Marshtomp    Water    Ground    405   70      85       70     50
# 260      Swampert    Water    Ground    535  100     110       90     60
# 261     Poochyena     Dark       NaN    220   35      55       35     35
# 262     Mightyena     Dark       NaN    420   70      90       70     70
# 263     Zigzagoon   Normal       NaN    240   38      30       41     60
# ...

# %% [markdown]
# #### Q. 각 Generation 별로 체고 강한 포켓몬의 total 크기는??

# %%
# Answer
# Out:
# Generation
# 1    680
# 2    680
# 3    680
# 4    720
# 5    680
# 6    680
# Name: Total, dtype: int64

# %% [markdown]
# #### Q. Generation 별로 Total의 백단위 그룹 수는?
# Tip) 100단위로 total을 나눈 column을 먼저 만들어보세요.

# %%
pokemon["Total_100"] =

# %%
# Answer
# Out:
# Generation  Total_100
# 1           100           2
#             200          17
#             300          50
#             400          49
#             500          30
#             600           3
# 2           100           1
#             200          17
#             300          23
#             400          34
#             500          21
#             600           4
# 3           100           3
#             200          26
#             300          30
#             400          53
#             500          13
#             600          10
# 4           100           1
#             200          11
#             300          24
#             400          30
#             500          30
#             600          10
#             700           1
# 5           200          17
#             300          48
#             400          56
#             500          27
#             600           8
# 6           200           7
#             300          22
# ...
