# %%
import numpy as np
import pandas as pd

# %%
# !pip install xgboost
# Out:
# ...
#     100% |████████████████████████████████| 645kB 223kB/s ta 0:00:01
#     Complete output from command python setup.py egg_info:
#     ++ pwd
#     + oldpath=/private/var/folders/y1/1sd072rd2h159qz2xrp00mnh0000gp/T/pip-build-lxpj25ru/xgboost
#     + cd ./xgboost/
#     + echo darwin17
#     + grep -q darwin
#     + LIB_XGBOOST=libxgboost.dylib
#     + which g++-5
#     + which g++-7
#     + which clang++
#     /usr/bin/clang++
#     + export CC=clang
#     + CC=clang
#     + export CXX=clang++
#     + CXX=clang++
#     + make clean
#     Makefile:31: MAKE [/Applications/Xcode.app/Contents/Developer/usr/bin/make] - checked OK
#     rm -f -rf build build_plugin lib bin *~ */*~ */*/*~ */*/*/*~ */*.o */*/*.o */*/*/*.o #xgboost
#     rm -f -rf build_tests *.gcov tests/cpp/xgboost_test
#     if [ -d "R-package/src" ]; then \
#     		cd R-package/src; \
#     		rm -f -rf rabit src include dmlc-core amalgamation *.so *.dll; \
# ...
