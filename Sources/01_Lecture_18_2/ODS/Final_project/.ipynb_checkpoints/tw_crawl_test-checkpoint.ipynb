# %%
import pandas as pd
import re

# %%
## 트위터 api 준비
from twython import Twython

APP_KEY='9YZNN1Nec1BnHApzLseYtEIi8' 
APP_SECRET='ktUDazXe5Qmkn8OFgKs8KO9KIWycIuCxD1kPCRF8RwEkVuaE3Z'
OAUTH_TOKEN='1061859779008557056-yRZX6t2HSJyQmuaFY0CpuJbkaybSpu'
OAUTH_TOKEN_SECRET='ifIbGQDOiIX3To6tX3IRCdKdb3pALwh2gHEgLCG7L0aCL'

twitter = Twython(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)

# %%
## 함수에 넣기위한 일주일 날짜 저장
from datetime import datetime, timedelta

# %%
ymd = []
for i in range(7):
    day = datetime.today()- timedelta(i)
    ymd.append('%s-%2s-%s' % ( day.year, day.month, day.day ))

# %%
##영화제목 지정
mvName = '국가부도의 날'

# %%
## 일주일간 일간 최대 100개의 twit 검색하여 testdata 생성
raw_test = []
for til in ymd:
    tweets = twitter.search(q=mvName, count=100, until = til)
    #data = [(t['user']['screen_name'], t['text'], t['created_at']) for t in tweets['statuses']]
    data2 = [t['text']  for t in tweets['statuses']]
    raw_test = raw_test + data2

# %%
##텍스트 전처리 후 저장
# RT @ 제거
st1 = list(map(lambda x : re.sub(r'\bRT\s*@(\w+):','',x) , raw_test))
# 특수문자등 제거
st2 = list(map(lambda x : re.sub(r'[^\s\d\w]','',x) , st1))
# url 제거
st3 = list(map(lambda x : re.sub(r'http[a-zA-z0-9]*','',x) , st2))
re_test = pd.DataFrame(list(set(st3)))
re_test.to_csv('re_test.csv')

# %%
re_test.values
# Out:
# array([[' 국가부도의 날 츄잉챗 \n\n김혜수 배우 채팅 '],
#        ['김혜수가 아닌 뱅상 카셀을 굳이 메인으로 내세운 것은 그러려니 한다면 lt국가부도의 날gt의 유아인이 어떤 위치에 있는가를 노골적으로 드러낸 커버라고 생각한다 '],
#        [' 님들 수요일에 국가부도의날 개봉하는거 아시져 문화의 날이라 영화표도 싸니까 꼭 보셔야해요 김혜수가 다해먹어요 예 믿고보세요 젤 중요한거 한지민배우랑 투샷을 볼 수 있다구요'],
#        [' 진짜 그렇네  33년 차 배우 김혜수가 누군가의 연인이 아닌 알탕 속의 꽃이 아닌  남성 쪽의 시선을 배제한 전문적이고 주체적인 여성 그 자체를 연기한 건 국가부도의날이 처음 그동안 알탕 충무로가 여배우들을'],
#        ['2ship8 완타 개빻앗대서 실어 국가부도의 날은 애호박빼면 괜찮고 성난황소는 시사회 엄청 돌리던데역시 곰냥처럼 ㄱ영주가 답이다'],
#        [' 국가부도의 날 김혜수 조카 보여줄 만한 영화 못 했었는데\n\n응 우리 아기 볼 수 있어\n\nㅠㅠㅠㅠㅠㅠㅠ오오어우어어어우엉우어우ㅠㅠㅠㅠㅠㅠ \n\n언니 사랑해 나 13살이야 '],
#        [' 국가부도의날 예매율 2위 됐음\n\n여러분 다들 김혜수 보러 갑시다 '],
#        ['이불에서 나가면 커피타먹고 국밥해먹고 국가부도의날보고와서 공부는할까'],
#        ['내가 국가부도의 날 개봉일을 알았더라면 이 이후에 출국했을 텐데 아까비 ㅠㅠㅠㅠㅠ'],
#        ['아 국가부도의 날 진짜 보고싶담'],
#        ['louissarang 아하 글쿠만 좋다좋다\n나도 후드보려구\n국가부도의날도 볼꺼구'],
#        ['국가부도의 날 김혜수x유아인에 IMF 스토리까지안 볼 수가 없네 오늘의개봉\n \n\n국가부도의 날 개봉을 축하합니다\n\n대박행진 궈궈궈 '],
#        [' 영화lt국가부도의날gt\nMBCFM4U\nFM영화음악 한예리입니다\n오늘 밤 2000\n조우진 '],
#        [' 국가부도의 날이 여성 캐릭터 한시현에게 가장 중요한 지위를 부여한다 하더라도 그녀는 여전히 남성 캐릭터들에 둘러싸여 있고 그녀에게 페미니즘적 주체성이 인상적으로 부과되고 있는지도 의문이다 그러나 그래서 어떻단'],
#        [' 국가부도의 날 후기\n\n한시현 영웅물입니다 김혜수 배우님은 시종일관 간지작살개멋짐터지고 은 시종일관 재수없어요 여성이라는 이유만으로 무시당하고 과소평가되는 과정이 정말 잘 그려져있는 영화입니다 요새 이만한 한'],
#        ['신동범 폭망한거 진짜 개꼬시다ㅋㅋㅋㅋ오늘 메박 들어가보니까 국가부도의날이 1위임'],
#        [' 김혜수 국가부도의 날 나는 어떤 어른인가 돌아보게 해\n\n국민은 전혀 몰랐잖아요\n\n '],
#        [' 뮤트합니다 송혜교 배우 주연 tvN드라마 lt남자친구gt 11월 28일 개봉 김혜수 배우 주연 영화 lt국가부도의 날gt 어제 개봉한 샤를리즈 테론 주연 영화 lt툴리gt 봅시다 여러분'],
#        ['국가부도의 날\n거미줄에 걸린 소녀\n\n내일 개봉 '],
#        [' 청룡땜에 묻힐까봐 조금 걱정인데\n여러분 lt국가부도의 날gt 개봉이 4일 남았어요\n김혜수가 1년만에 진짜 좋은 작품으로 돌아왔으니까 제발 꼭 좀 봐주세요 '],
#        ['친구랑 국가부도의날 보기로 했다'],
#        [' 오늘 저녁 7시반 국가부도의 날 츄잉챗'],
#        ['국가부도의 날 개봉일 30만역대 11월 韓영화 최고 오프닝공식  '],
#        [' 허스토리 왜 레즈영화라고 말 안 해줫어\n국가부도의 날 왜 레즈영화라고 말 안 해줬ㅅ어 '],
#        ['바로 내일 lt국가부도의 날gt 개봉\xa0  \n우리 모두 극장에서 만나요\n\n지금 바로 각 극장사이트에서 예매 GO\n\n국가부도의날 김혜수 유아인 허준호 조우진 뱅상카셀 '],
#        ['오늘 보랩 보고 내일 국가부도의 날 볼까'],
#        [' 국가부도의날 무대인사 무인 양도\n\n1일\ncgv영등포 스피어엑스관 1605\nA열 중블 연석 2자리 24\n\n2일\ncgv압구정 3관 2030\nC열 오블 통로 연석 2자리 22\n\n모두 원가양도입니다\n\n김혜수 유아인 '],
#        [' 퀴즈하나에 오디오물림 무엇소리주의ㅋㅋ\n퀴즈 열정이 유노윤호급\n\nlt국가부도의 날gt 네이버 무비토크 풀 버전 보기\n\n\n네이버무비토크_1탄 국가부도의날 김혜수 유아인'],
#        ['국가부도의 날 빨리 보고싶은데 개봉 은제 하지'],
#        [' 조만간 볼 영화\n\n국가부도의 날 1128 개봉\n거미줄에 걸린 소녀 1128 개봉\n모털 엔진 125 개봉\n\n멋있는 여자들 장마니 나옴 많이들 봐주쇼 '],
#        ['내일은 문화의날 근데 성난황소랑 국가부도의 날 말곤 시간대 거지라서 못봄'],
#        [' 국가부도의 날 보세요 두 세 번 보셔도 됩니다 이거 보는 사람들 정말 진한 혜수 준호 우진을 하자'],
#        ['limkunsoon anubodhana CJ에서 배급하고 좌빨 유아인 주연 국가부도의 날은 대대적으로 지상파에서 홍보중이다 개대중 놈현 실정다룬 영화도 만들어봐라 특히 개대중 대북불법송금 북해개발 '],
#        ['국가부도의 날 예매햇다'],
#        ['사랑합니다 국가부도의 날 봐야겟다 참아야지 모 걔는 꾹 참어야지'],
#        ['DA인터뷰① 김혜수 국가부도의 날 반드시 만들어져야 했던 영화 '],
#        ['갓혜수의 흥행 마법국가부도의 날 철옹성 보랩 꺾고\xa01위  '],
#        ['국가부도의 날 GV 12편 질문amp답변 '],
#        [' 혜수언니 국가부도의날 때문에 5개월간 영어와 경제 강의를 들으셨다니 진짜 꼭 봐야겠다ㅠㅠ 안볼이유가 없고요 '],
#        [' 유아인 도올 국가부도의 날을 말하다 유아인 산삼 먹다 \n도올TV 에 유아인 출연 이 조합은 상상을 못했다 \n\n  '],
#        [' 국가부도의 날 김혜수 조우진 배우님의 연기가 마치 불과 얼음 같은 대립구도로 스크린을 압도한다 원탑은 김혜수 배우가 맞고 분량이며 임팩트며 조우진 배우가 실질적인 남주라고 느껴짐 허준호 배우님의 연기도 굉장히 울림'],
#        ['영화 국가부도의 날 시사회 후기  곽동명 영화 기자 우석훈 박사 신촌아트레온 GV 풀영상스포O   국가부도의날 영화국가부도의날 국가부도의날시사회 '],
#        [' 엘르 영화국가부도의날'],
#        ['국가부도의 날도 일단 보고 판단할까봐\n여성1을 알탕에 끼워놓는 구도에 너무 많이 데여서 경계했지만'],
#        ['dywjddlqslekg 엌ㄱㅋㄱ ㅋㄱ 난 국가부도의날볼것'],
#        ['오 애들한테 국가부도의 날 보자해야지 '],
#        [' 국가부도의 날 김혜수가 멱살잡고 끌고 간다는 수준으로 돋보이는 영화인데 홍보에는 유아인이 먼저 나오고 손더게도 명백히 삼주연인데 정은채 주연취급 못 받고 종방 후 인터뷰 하나 없는거 이건 커리어 뺏긴게 분명하다'],
#        [' 무대인사 일정 국가부도의 날서울 김혜수 유아인 허준호 조우진 참석 예정 '],
#        ['문별이 복가출연때메 복가 마마무멤버 별로 다 돌려보다가 우비소녀 박진주님까지 영상 다보게됐는데 그때도 기분좋앗고 박진주님께 엄청난 매력을 느꼇지만 이번에 또 다시 좋아하게 됏다 너무 좋아 입덕이야 그리고 이 '],
#        [' 여러분 김혜수가 1년 만에 주연을 맡은\n국가부도의날 보세요 '],
#        ['국가부도의날이 28일 오늘 개봉합니다\n\n볼까 말까 아직 고민 중이라면 그냥 보세요\n고명 하나 때문에 국수를 안 먹을 순 없습니다 '],
#        ['인터뷰 lt국가부도의 날gt에 담긴 특별한 마음들 영웅 아닌 본분의 영화\n\n여성의 영화 아닌 신념의 영화\n올바른 신념을 갖는다는 것\n영화적 재미 '],
#        [' 영화lt국가부도의날gt무대인사 일정  일시  12월 1일  12월2일  참석자   배우  김혜수 유아인 허준호 조우진 '],
#        [' 국가부도의 날 무대인사 원가양도\n\n다 중블 입니다\n\n예매번호 전송뒤 취소X\n\n\n\n국가부도의날 국가부도의날무대인사 국가부도의날무인 국가부도의날원가 국가부도의날원가양도 김혜'],
#        [' 말해줘 나에게 말해줘\n조우진 노래에 혜수언니 잔망까지 보면 을매나 좋게요\n\nlt국가부도의 날gt 네이버 무비토크 풀 버전 보기\n\n\n네이버무비토크_2탄 국가부도의날 '],
#        [' 국가부도의 날 꼭 보세요 봐야합니다 애호박이 묻어서 안 볼래 재미없을 것 같아라고 생각하시고 안 보시면 앞으로 여성 서사 영화들은 더 줄어들 거라고 생각해요 이제 막 여성 서사 영화들이 생겨나고 관심받는 이 시기에 나온'],
#        [' lt국가부도의 날gt을 꼭 봐야겠다는 마음은 단순히 김혜수가 중심인 영화라는 이유로 애호박 못버려가 아니다물론 그이유만으로도 볼수있음  김혜수가 이렇게까지 같은 직업 분야의 여성들과 연대하는데 나도 김혜수가 출연한 영'],
#        ['국가부도의날은 김혜수랑 뱅상카셀 둘이 붙는 장면 너무 좋아서 극장에서 또 보고 싶은데 이거 보려고 UAㅏ인의 해괴한 연기를 또 볼 자신이 없음 처음엔 모르고 그냥 본거지만 이제 어떻게 연기했는지 이미 아는 상태에서 또 보는건 정말 고문이라서'],
#        [' 오늘 저녁 7시 30분 국가부도의 날 라이브톡'],
#        [' 툴리도 남배우 캐스팅때 국가부도의 날처럼 같은 문제에 부딪쳤다고함 샬리즈와 비슷한 커리어를 갖은 남배우들을 고려했었는데 여성 주인공을 서브하는 역을 꺼려했었다고'],
#        [' 국가부도의날 개봉 이제 하루 남았다룰루\n킹갓 김혜수 보러갑시다 '],
#        [' 20181127\nlt국가부도의 날gt 츄잉챗\n허준호 김혜수 조우진 국가부도의날 '],
#        [' 유아인 진짜 국가부도의날에서 돈 없는 조태오였음 약간 분조장 있는거 같은 억눌린 조태오'],
#        [' 181126 국가부도의날 스라톡\n혜수배우님 갓혜수 '],
#        ['오늘은 퇴근하고 국가부도의날을 볼거야'],
#        ['YouTube 동영상  김스카이의 영화 국가부도의 날 해설강의 feat 채희선 amp 신동훈에'],
#        ['국가부도의날 존나봐보고싶은데\n개빵빵한사운드와 짱큰화면으로\n유아인얼굴목소리 인식하게되면은\n존나개빡쳐서토할거같음'],
#        [' 국가부도의 날 유아인 대중에 대한 예의 반영된 감독의 신뢰 느낀 작품\n \n그동안 놀랍게도 큰 사랑을 받았어요 국가부도의 날은 관객들에게 한 발짝 가깝게 다가가고 싶'],
#        ['국가부도의날볼까\n영주보고싶어'],
#        [' 오늘 저녁부터 방송 스타뜨\n주말까지 lt국가부도의 날gt과 함께 하세요\n안방1열 사수 필수\n\n국가부도의날 김혜수 유아인 허준호 조우진 뱅상카셀 11월28일대개봉 '],
#        [' 상처뿐인 시대를 복기하면서 각자가 했던 선택들 그 거대한 소용돌이가 바꿔놓은 현 시대와 그 속의 나를 한 번쯤 돌아보길 바라요 서로의 경험을 나누고 20년의 세월을 반추하는 매개체가 된다면 그걸로 충분하지 않을까요'],
#        ['국가부도의 날 보기 전 확인해야 할 것To See or Not to See '],
#        ['IMF를 다룬 국가부도의날 영화 개봉에 기대어 느끼자면\nIMF는 경제를 시발점으로 사회가 무너져 각자도생으로 가는 하나의 과정이었다면 지금은 MB503을 거치며 정치를 시발점으로 사회가 무너져 또 한번 '],
#        ['근데 김혜수는 국가부도의 날 다음작품 잘되면 되지 유아인은 걍 나오는 것마다 망했으면 좋겠는데'],
#        [' 김혜수는 국민이 장롱 속 아이 돌반지와 할머니 가락지까지 끄집어내 동참했던 금 모으기로 모인 돈이 결국 대기업 부채를 갚는 데 쓰였다는 사실을 읽고 어떻게 분노하지 않을 수 있느냐고 되물었다\n\n국가부도의날 열'],
#        ['아근데 국가부도의날 유아인땜에 안본다는 페미 약간 이해가 안댐 남성을 향한 분노가 여성을 향한 사랑보다 더 크고 깊다는게 이해가 안된다기보단 공감이 안된다구 해야하나 가치순위가 전도됐다는 느낌 떨칠수없다'],
#        ['유아인 연기 점점 원패턴으로 고정되는 거 같다 국가부도의 날 유아인 여전히 흥분하고 사짜냄새나는 연기라 캐릭터가 나타내고 싶었던 바를 제대로 구현하지 못함 감독들도 그거 알아서 원패턴 연기로만 기용하 '],
#        [' 기다리고 기다리던 lt국가부도의 날gt 무대인사\n개봉 1주차 주말 무대인사 확정\n김혜수X유아인X허준호X조우진과 극장에서 만나요\n\n예매는 극장 사정에 따라 순차적으로 오픈 예정입니다\n\n국가부도의날 김혜수 유'],
#        ['보헤미안 랩소디 500만 돌파 확실개봉한 국가부도의 날 예매율\xa01위 '],
#        [' 작품에 적극적이지 않으면 그런 마음도 들지 않았겠죠 이제는 더 많이 가깝게 다가가고 소통하고 공유하고 싶다는 마음이 들었어요 간지럽지만 이런 제 마음을 알아줬으면 좋겠어요 그런 것들이 국가부도의 날과 윤정학에게'],
#        [' 181126 국가부도의날 \n김혜수배우님 '],
#        ['오늘 저녁 7시반 국가부도의 날 츄잉챗'],
#        [' 강조하고 싶은 것은 지리멸렬한 성차별의 역사로 가득한 한국영화계라는 구체성에 맞서 비록 그 성취가 미진할지라도 국가부도의 날이 페미니즘을 경유해 호명되어야 하고 대중화되어야 하며 성공을 거둬야 한다는 어떤 시급한 당위'],
#        [' 여성감독 여성주연 영주 내일 개봉입니다\n현재 상영시간표가 현저히 적은데 우린 다시 기적을 이끌어 낼 것이라 생각합니다 국가부도의날ㅋ 김혜수 주연이라고 소비하신 분 영주는 안볼꺼 아니지 '],
#        [' 올해안에 보고싶은 개봉예정 여성주연 영화들\nlt11월gt\n28일 국가부도의 날거미줄에 걸린 소녀\n29일 소녀의세계다이빙\nlt12월gt\n5일 모털엔진도어락\n6일 호두까기인형\n12일 부탁하나만들어줘\n13일 갈매기'],
#        ['대한제국전시 국가부도의날 보러갈 사람 구합니당'],
#        [' 국민이 장롱 속 아이 돌반지와 할머니 가락지까지 꺼내 동참했던 금 모으기로 모인 돈이 결국 대기업 부채를 갚는 데 쓰였다는 사실을 읽고 어떻게 분노하지 않을 수 있느냐\n\n영화 국가부도의 날에 출연한 김혜수의 말'],
#        ['lt툴리gt 보신분들 많겠지만 왠지 스포될까봐 못쓰겠다 뭔가 스스로 가야할 때를 알았다는 것이 내 룸곡버튼이었다는 것 밖에ㅠㅠ lt국가부도의날gt은 이미 벌어진 상황이라 어쩔수없는 답답함을 견뎌야했고'],
#        ['이번 주에는 내 픽 국가부도의 날과\n남편 픽 보헤미안 랩소디를 볼 거다 꼭'],
#        [' 손예진 배우 때문에 협상 봤습니다 정유미 배우 때문에 82년생 김지영 봤습니다 김혜수 배우 때문에 국가부도의 날 봤습니다 말하는 게 한남배우 묻었다고 불매하는 것보다 한국 여성중심서사 영화를 늘리는 데 훨씬 유효하'],
#        ['ㅎㅏ애호박\n영화 국가부도의 날 \n사람들 애호박 나온다고 좋아하며\n보러가는 모습에 벌써부터 빡친ㄷㅏ\n뭐 보는건 지들 맘이지만\n프로불편러인 나는 애호박때문에\n빡친다'],
#        [' 보헤미안 랩소디 500만 돌파 확실개봉한 국가부도의 날 예매율\xa01위 '],
#        [' 181126 국가부도의날\n허준호 김혜수 배우님 '],
#        ['국가부도의 날 속 접속 포스터 등장한 이유  '],
#        [' 국가부도의 날 보러 갔다가 겟겟 '],
#        [' 국가부도의 날 무대인사 원가양도\n\n예매번호 전송뒤 취소X\n\n\n\n국가부도의날 국가부도의날무대인사 국가부도의날무인 국가부도의날원가 국가부도의날원가양도 김혜수 유아인 조우'],
#        [' 국가부도의날 예매율 올랐다 아까 5위였는데 4위됐어ㅜㅜㅜ28일 문화의날 저녁엔 5000원에 볼 수 있습니다 둘이 가도 만원 예매 하세용 '],
#        [' 국가부도의 날에 유아인이 나온다는 이유로 김혜수 주연작이라도 밀어주기 싫다는 분들은 영주는 열심히 밀어주시겠죠 툴리도 열심히 보시겠죠 물론 저는 셋 다 볼 거지만요 '],
#        ['아니 국가부도의 날 김혜수 배우님 나오셔서 보러 갈까 ㅅ애각중이었는데 ㅇㅇㅇ 나오네'],
#        ['예매율 1위 국가부도의 날 500만 보헤미안 랩소디 기세 꺾을까 Oh 무비\n\n'],
#        ['국가부도의날 개봉 첫 날 30만 돌파1위 등극 美친box\n\n  '],
#        ['다작을 했지만 국가부도의 날이 스크린 첫 주연작이다 소회가 남다를 것 같다\n\n주연 맞나 실감이 안 난다 사실 분량에 대해서는 굳이 연연하지 않는다 그런 것에 대해 의식하고 그랬던 것 같지는 '],
#        [' lt국가부도의 날gt을 꼭 봐야하는 이유무려 주연이 김혜수인데 김혜수한테 가려진다는 이유로 출연을 거절한 젊은 남자배우들 시건방짐이 꼴보기싫어서라도 꼭 본다 '],
#        ['영화lt국가부도의날gt\nMBCFM4U\nFM영화음악 한예리입니다\n오늘 밤 2000\n조우진 '],
#        [' 국가부도의날 무대인사 12월 2일 일요일\n김혜수 유아인 조우진 허준호 참석\nCGV건대입구 1310 중블 B열 연석 원가양도합니다\n디엠주세요\n국가부도의날무대인사 국가부도의날 무대인사 김혜수 유아인'],
#        ['ㅇㄴㅋㅋ ㅋ ㅋㅋ ㅋㅋ ㅋ ㅋ ㅋㅋ 그린델왕드 그거 본다는 애들 2명이라 행복햇는데 국가부도의ㅜ날에 애호박 나온다맼큐ㅠㅠㅠㅠㅠㅠㅠㅠ 진짜 싷다 13명으오 국가부도 갈렷는데ㅠㅠㅠㅠㅜㅜ 다른 반 애들은 뭐햇늘지 모르게다ㅠㅠㅠㅠ'],
#        ['국가부도의 날 개봉'],
#        ['Sirarion_171 응ㅋㅋㅋㅋ ㅋㅋ 난 남의 등록금을 영화보는 데 썼다 12월 7일인가 그때 영화 다른 거 보러 간대 아마 국가부도의날 볼 것 같어'],
#        ['yplovejhreal 제가 지금 국가부도의 날이 아니라 유화부도의 날 찍게생겨서요 살만해지면 혹시 블루레이 같은 거 나왔나요 시나리오북이나 그런거라도 사겠습니다'],
#        [' 국가부도의 날 스포합니다\n한국 결국 IMF 구제금융 받음ㅠㅠ'],
#        ['국가부도의 날 보는날 마라탕 먹고싶은데 시간대가 애매애매'],
#        [' 국가부도의 날 보세요 '],
#        [' ㅎㅎㅎㅎㅎㅎㅎ\nㅎㅎㅎㅎㅎ\n국가부도의 날에 김혜수\n한지민 같이 나온댛ㅎ\nㅎㅎㅎ\nㅎㅎㅎㅎ\nㅎㅎㅎㅎㅎㅎ\nㅎㅎㅎㅎㅎㅎㅎㅎㅎ\n홓ㅎㅎㅎㅎㅎ\n아 행복ㅎㅎㅎㅎ '],
#        [' 툴리 영주 부탁하나만들어줘 국가부도의날'],
#        [' 여배우들 덕질하는 입장에선 국가부도의 날 불매 얘기 너무 답답하다 진짜 여배우들이 여배우한테는 시나리오가 안 들어온다고 몇 번이나 얘기하고 자기들도 남배우들이 하는 역할 하고 싶다고 몇 번이나 말했는데'],
#        [' 국가부도의날에 용찬본체 나오는데 배역이름이 현수야ㅋㅋㅋㅋ '],
#        ['국가부도의날 김혜수 누워서 시나리오 보다 벌떡 일어났죠 '],
#        [' 아니 울애기 미모 일낸거 왜 암두 안알랴줘써 국가부도의날 보러왓는데 내맘부터 부도났어 하 박지민\n\nMAMAVOTE BTS BTS_twt '],
#        ['유아인 진짜 국가부도의날에서 돈 없는 조태오였음 약간 분조장 있는거 같은 억눌린 조태오'],
#        ['동영상을 YouTube 재생목록  국가부도의 날 GV 12편 질문amp답변에 추가했습니다'],
#        [' 배우들 진짜 연기 어케 저러케 하지 나같으면 자아정체성 혼란 존나 올듯 최근에 창궐에서 조우진 보고 와 존멋탱 했는데 지금 국가부도의날에서는 진짜 죽빵맹이 처날리고시픔'],
#        ['국가부도의날 121\n영등포CGV 1840\n무대인사 \nA열한장 뎀주세요'],
#        ['국가부도의 날 무대인사 원가양도\n\n다 중블 입니다\n\n예매번호 전송뒤 취소X\n\n\n\n국가부도의날 국가부도의날무대인사 국가부도의날무인 국가부도의날원가 '],
#        ['lt국가부도의 날gt을 꼭 봐야겠다는 마음은 단순히 김혜수가 중심인 영화라는 이유로 애호박 못버려가 아니다물론 그이유만으로도 볼수있음  김혜수가 이렇게까지 같은 직업 분야의 여성들과 연대하는데 나도 '],
#        [' 영화 국가부도의 날에서 한시현 역을 맡은 32년 경력의 배우 김혜수는 다음과 같이 말했다 전문성이 주가 된 인텔리 여성 캐릭터는 처음 맡아봤다\n'],
#        [' 허스토리미쓰백국가부도의 날까지올해 2018여성영화의 모든순간엔 한지민이 함께하고있다'],
#        [' 국가부도의 날 봤음 주인공 한시현 역을 여성배우김혜수가 맡아 부패하고 무능력한 고위 남성관료들과 확실한 적대관계를 형성한다 여성 서사로서 좋은 예가 될 수 있다고 생각함'],
#        ['개봉하는보다는 개봉한이지만 국가부도의날도 합쳐서'],
#        [' 국가부도의날 영화를 보고 왔다\nIMF를 새로운기회라고 생각한다는 정치인조우진\n가난한 사람은 더욱더 가난해진다김혜수\n난 속지않아유아인\n영화마지막에 자막글귀에  IMF위기에  금모으기 돈이 기업부채에 쓰였다\n이게'],
#        ['영화 국가부도의 날 아직 보지 않았지만 남한의 IMF 사태를 다룬 영화 베스트를 꼽으라면 나는 기억의 밤을 꼽을 것 같다'],
#        ['문화계도 죄다 좌빨로 썩어서 울 동내 메가박스와 CGV는 출국 상영안한다 지난주는 작은 상영관에서 조조와 늦은 시간대만 하더니 이 마저도 상영접었다 배급사 CJ의 좌빨 유아인 주연의 국가부도의 날은 개봉 '],
#        ['국가부도의날 언제보지 혜수언니 무인오면 좋겠다 예전에 정말 눈부신 여신이었던 기억'],
#        [' 개봉 전이라 길게 말할 수 없지만 국가부도의 날 꼭 보십쇼 두번 보십쇼 애호박 하나 때문에 거른다 빈대잡자고 초가삼간 태운다는 속담은 이럴때 쓰는 말입니다 그리고 초가삼간이 아니라 대궐입니다 김혜수가 갓킹으로 있는'],
#        [' 갑자기 국가부도의날 생각난것도 김혜수 캐릭터를 그냥 좀 신선한 서사를 위해 여자로 만들었다는 얘기 들은게 생각나서 성별만 여자로 바꿔도 다이나믹이 얼마나 달라지는지 모두가 아는데'],
#        ['나는 아직 본거라곤 국부 메인예고편밖에 없지만 진짜 잘 되어서 김헤수 하면 그 말아먹을 타짜 그만 얘기하고 국가부도의 날 한시현 얘기가 먼저 나왔음 좋겟다']],
#       dtype=object)
