# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('schedule_outputput_all.csv',encoding='UTF8')

# %%
df.head()
# Out:
#     date opposition result  batter_no position  is_starter  AB  R  H  2B  ...  \
# 0  03-24        @NC  L 2:4          4       3B           1   3  1  1   0  ...
# 1  03-25        @NC  L 1:7          4       3B           1   4  0  0   0  ...
# 2  03-27        @넥센  L 4:5          4       3B           1   5  0  1   0  ...
# 3  03-28        @넥센  W 9:3          4       3B           1   5  1  1   0  ...
# 4  03-29        @넥센  L 4:9          4       3B           1   4  0  1   0  ...
#
#      OPS  투구  avLi  RE24    WPA  year  cur_team  team  batter_name   year_born
# 0  0.833  15  1.17  0.52  0.043  2018        LG    LG         가르시아  1985-04-12
# 1  0.393  13  0.66 -1.08 -0.065  2018        LG    LG         가르시아  1985-04-12
# 2  0.397  15  1.49 -0.78 -0.039  2018        LG    LG         가르시아  1985-04-12
# 3  0.399  10  0.65 -0.36  0.061  2018        LG    LG         가르시아  1985-04-12
# 4  0.408  14  0.61 -0.53 -0.032  2018        LG    LG         가르시아  1985-04-12
#
# [5 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['date', 'opposition', 'result', 'batter_no', 'position', 'is_starter',
#        'AB', 'R', 'H', '2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP',
#        'IBB', 'K', 'GDP', 'SH', 'SF', 'avg2', 'OBP', 'SLG', 'OPS', '투구',
#        'avLi', 'RE24', 'WPA', 'year', 'cur_team', 'team', 'batter_name',
#        'year_born'],
#       dtype='object')

# %%
df[[ 'batter_name',
       'year_born','year',  'team', 'cur_team','date', 'opposition', 'result', 'batter_no', 'position', 'is_starter',
       'AB', 'R', 'H', '2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP',
       'IBB', 'K', 'GDP', 'SH', 'SF', 'avg2', 'OBP', 'SLG', 'OPS', '투구',
       'avLi', 'RE24', 'WPA']]
# Out:
#       batter_name   year_born  year team cur_team   date opposition   result  \
# 0            가르시아  1985-04-12  2018   LG       LG  03-24        @NC    L 2:4
# 1            가르시아  1985-04-12  2018   LG       LG  03-25        @NC    L 1:7
# 2            가르시아  1985-04-12  2018   LG       LG  03-27        @넥센    L 4:5
# 3            가르시아  1985-04-12  2018   LG       LG  03-28        @넥센    W 9:3
# 4            가르시아  1985-04-12  2018   LG       LG  03-29        @넥센    L 4:9
# 5            가르시아  1985-04-12  2018   LG       LG  03-30        KIA    L 3:4
# 6            가르시아  1985-04-12  2018   LG       LG  03-31        KIA    W 6:4
# 7            가르시아  1985-04-12  2018   LG       LG  04-01        KIA    W 6:5
# 8            가르시아  1985-04-12  2018   LG       LG  04-03        @두산    L 4:5
# 9            가르시아  1985-04-12  2018   LG       LG  04-04        @두산    L 3:6
# 10           가르시아  1985-04-12  2018   LG       LG  04-06        @롯데   W 14:6
# ...
